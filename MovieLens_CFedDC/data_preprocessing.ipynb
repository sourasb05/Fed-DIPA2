# %%
import pandas as pd
import os
cwd = os.getcwd()
# For 1M dataset
df = pd.read_csv(cwd + "/data/ratings.dat", sep="::", engine="python",
                 names=["user_id", "item_id", "rating", "timestamp"])

print(df.head())
print(df.shape)
# Out:
#    user_id  item_id  rating  timestamp
# 0        1     1193       5  978300760
# 1        1      661       3  978302109
# 2        1      914       3  978301968
# 3        1     3408       4  978300275
# 4        1     2355       5  978824291
# (1000209, 4)
