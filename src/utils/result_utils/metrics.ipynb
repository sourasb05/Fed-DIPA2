# %%
import matplotlib.pyplot as plt

# %%
accuracy = [ 0.7815277814865113, 0.7871296286582947, 0.7911111116409302, 0.7948333323001862, 0.7984259307384491, 0.8009523689746857, 0.8038541734218597, 0.8023456811904908, 0.8026111125946045, 0.8034090876579285, 0.8028009295463562, 0.8053418755531311, 0.8081150829792023, 0.806981486082077, 0.8046527802944183, 0.8048856258392334, 0.8057716071605683, 0.8073830425739288, 0.8084444582462311]
precision = [ 0.503853702545166, 0.5381764724850655, 0.5464209273457528, 0.5543782725930214, 0.564019787311554, 0.5776365697383881, 0.58770452439785, 0.583076536655426, 0.5809345662593841, 0.5811971694231033, 0.5853165268898011, 0.5921619981527328, 0.5998766094446182, 0.5975767105817795, 0.579774272441864, 0.5792509853839874, 0.5812849909067154, 0.5854825675487518, 0.5879896283149719]
recall = [ 0.4943939447402954, 0.5280303090810776, 0.5410984888672828, 0.5459394037723542, 0.5508333384990692, 0.5588095381855964, 0.5675189435482025, 0.5704040445387364, 0.5652121223509312, 0.5661294728517532, 0.5712499998509883, 0.5771561808884144, 0.5786471880972386, 0.5759090930223465, 0.5741666696965695, 0.5777629353106022, 0.578409094363451, 0.5786523126065731, 0.5780757643282414]
f1 = [ 0.4670735999941826, 0.5028783410787583, 0.5150326356291771, 0.5217614635825157, 0.5280332297086716, 0.5374014124274253, 0.5455556318163872, 0.5433871865272522, 0.5405942112207412, 0.5410996153950691, 0.5438461676239967, 0.5493788957595825, 0.5538525745272637, 0.5507428035140037, 0.5476087421178818, 0.5486106619238853, 0.5503220990300178, 0.5528983190655709, 0.5538367904722691]

# %%
# Creating subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Performance Metrics Over Iterations')

# Plot each metric
axs[0, 0].plot(accuracy, label='Accuracy', color='b')
axs[0, 0].set_title('Accuracy')
axs[0, 0].set_xlabel('Iterations')
axs[0, 0].set_ylabel('Accuracy')

axs[0, 1].plot(precision, label='Precision', color='r')
axs[0, 1].set_title('Precision')
axs[0, 1].set_xlabel('Iterations')
axs[0, 1].set_ylabel('Precision')

axs[1, 0].plot(recall, label='Recall', color='g')
axs[1, 0].set_title('Recall')
axs[1, 0].set_xlabel('Iterations')
axs[1, 0].set_ylabel('Recall')

axs[1, 1].plot(f1, label='F1 Score', color='purple')
axs[1, 1].set_title('F1 Score')
axs[1, 1].set_xlabel('Iterations')
axs[1, 1].set_ylabel('F1 Score')

# Display the plots
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
