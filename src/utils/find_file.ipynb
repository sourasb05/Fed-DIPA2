# %%
from PIL import Image
import os

# Path to your folder containing the images
folder_path = "/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/dipa2/images"

# Name of the image file you want to open
image_name = "34b65dafe328d39e.jpg"

# Complete path to the image file
image_path = os.path.join(folder_path, image_name)

# Open the image
try:
    img = Image.open(image_path)
    img.show()
except FileNotFoundError:
    print(f"The image '{image_name}' was not found in the folder '{folder_path}'.")
