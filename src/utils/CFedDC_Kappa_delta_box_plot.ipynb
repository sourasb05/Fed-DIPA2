# %% [markdown]
# $\delta$ variable and $\kappa$ constant

# %%
import os
import glob
import json
import sys

cwd = os.path.abspath(os.getcwd())
p_cwd = os.path.abspath(os.path.join(cwd, "..", ".."))
print("Current working directory: {0}".format(p_cwd))
# Out:
# Current working directory: /proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2

# %%
k1_d01_path_test = p_cwd + '/results/client_level/CFedDC_KT_RL_rl1_C2_timm_mobilevit/exp_no_0_CFedDC_KT_RL_lambda_min_0.4_lambda_max_0.6_kappa_1.0_delta_0.1_30/local_test'
k1_d05_path_test = p_cwd + '/results/client_level/CFedDC_KT_RL_rl1_C2_timm_mobilevit/exp_no_0_CFedDC_KT_RL_lambda_min_0.4_lambda_max_0.6_kappa_1.0_delta_0.5_30/local_test'
k1_d08_path_test = p_cwd + '/results/client_level/CFedDC_KT_RL_rl1_C2_timm_mobilevit/exp_no_0_CFedDC_KT_RL_lambda_min_0.4_lambda_max_0.6_kappa_1.0_delta_0.8_30/local_test'
k1_d1_path_test =  p_cwd + '/results/client_level/CFedDC_KT_RL_rl1_C2_timm_mobilevit/exp_no_0_CFedDC_KT_RL_lambda_min_0.4_lambda_max_0.6_kappa_1.0_delta_1.0_30/local_test'

# Get a list of all JSON files in the directory

file_list_1 = glob.glob(os.path.join(k1_d01_path_test, '*.json'))
file_list_2 = glob.glob(os.path.join(k1_d05_path_test, '*.json'))
file_list_3 = glob.glob(os.path.join(k1_d08_path_test, '*.json'))
file_list_4 = glob.glob(os.path.join(k1_d1_path_test, '*.json'))

# %%
# Separate files into two categories
resourceless_files_1 = []
resourceful_files_1 = []
resourceless_files_2 = []
resourceful_files_2 = []
resourceless_files_3 = []
resourceful_files_3 = []
resourceless_files_4 = []
resourceful_files_4 = []

for file_path in file_list_1:
    with open(file_path, 'r') as json_file:
        try:
            # Parse the JSON file
            file_data = json.load(json_file)
            # Check the resource category and categorize the file
            if file_data.get('resource_category') == 'Resourceless user':
                resourceless_files_1.append(file_path)
            elif file_data.get('resource_category') == 'Resourceful user':
                resourceful_files_1.append(file_path)
        except json.JSONDecodeError as e:
            print(f"Error reading {file_path}: {e}")


for file_path in file_list_2:
    with open(file_path, 'r') as json_file:
        try:
            # Parse the JSON file
            file_data = json.load(json_file)
            # Check the resource category and categorize the file
            if file_data.get('resource_category') == 'Resourceless user':
                resourceless_files_2.append(file_path)
            elif file_data.get('resource_category') == 'Resourceful user':
                resourceful_files_2.append(file_path)
        except json.JSONDecodeError as e:
            print(f"Error reading {file_path}: {e}")

for file_path in file_list_3:
    with open(file_path, 'r') as json_file:
        try:
            # Parse the JSON file
            file_data = json.load(json_file)
            # Check the resource category and categorize the file
            if file_data.get('resource_category') == 'Resourceless user':
                resourceless_files_3.append(file_path)
            elif file_data.get('resource_category') == 'Resourceful user':
                resourceful_files_3.append(file_path)
        except json.JSONDecodeError as e:
            print(f"Error reading {file_path}: {e}")

for file_path in file_list_4:
    with open(file_path, 'r') as json_file:
        try:
            # Parse the JSON file
            file_data = json.load(json_file)
            # Check the resource category and categorize the file
            if file_data.get('resource_category') == 'Resourceless user':
                resourceless_files_4.append(file_path)
            elif file_data.get('resource_category') == 'Resourceful user':
                resourceful_files_4.append(file_path)
        except json.JSONDecodeError as e:
            print(f"Error reading {file_path}: {e}")

print("Resourceless user files:", resourceless_files_1)
print("Resourceful user files:", resourceful_files_1)
print("Resourceless user files:", resourceless_files_2)
print("Resourceful user files:", resourceful_files_2)
print("Resourceless user files:", resourceless_files_3)
print("Resourceful user files:", resourceful_files_3)
print("Resourceless user files:", resourceless_files_4)
print("Resourceful user files:", resourceful_files_4)
# Out:
# Resourceless user files: ['/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2_timm_mobilevit/exp_no_0_CFedDC_KT_RL_lambda_min_0.4_lambda_max_0.6_kappa_1.0_delta_0.1_30/local_test/user_100_test_round_results.json', '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2_timm_mobilevit/exp_no_0_CFedDC_KT_RL_lambda_min_0.4_lambda_max_0.6_kappa_1.0_delta_0.1_30/local_test/user_102_test_round_results.json', '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2_timm_mobilevit/exp_no_0_CFedDC_KT_RL_lambda_min_0.4_lambda_max_0.6_kappa_1.0_delta_0.1_30/local_test/user_103_test_round_results.json', '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2_timm_mobilevit/exp_no_0_CFedDC_KT_RL_lambda_min_0.4_lambda_max_0.6_kappa_1.0_delta_0.1_30/local_test/user_104_test_round_results.json', '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2_timm_mob
# ...

# %%
import json
import statistics

def calculate_stats_min_info_cmae(file_list):
    min_values = []
    for file_path in file_list:
        with open(file_path, 'r') as json_file:
            try:
                file_data = json.load(json_file)
                info_cmae = file_data.get('validation_results', {}).get('info_cmae', [])
                if info_cmae:
                    min_values.append(min(info_cmae))
            except json.JSONDecodeError as e:
                print(f"Error reading {file_path}: {e}")
    print(min_values)
    return min_values 

# Calculate for each group
min_rf_1 = calculate_stats_min_info_cmae(resourceful_files_1)
min_rl_1 = calculate_stats_min_info_cmae(resourceless_files_1)
min_all_1 = calculate_stats_min_info_cmae(file_list_1)

min_rf_2 = calculate_stats_min_info_cmae(resourceful_files_2)
min_rl_2 = calculate_stats_min_info_cmae(resourceless_files_2)
min_all_2 = calculate_stats_min_info_cmae(file_list_2)

min_rf_3 = calculate_stats_min_info_cmae(resourceful_files_3)
min_rl_3 = calculate_stats_min_info_cmae(resourceless_files_3)
min_all_3 = calculate_stats_min_info_cmae(file_list_3)

min_rf_4 = calculate_stats_min_info_cmae(resourceful_files_4)
min_rl_4 = calculate_stats_min_info_cmae(resourceless_files_4)
min_all_4 = calculate_stats_min_info_cmae(file_list_4)
# Out:
# [0.0048809051513671875, 0.9977736160868691, 1.5, 0.1826620101928711, 1.6346052169799805, 1.3339018821716309, 0.8732100526491801, 1.017386926545037, 1.6325974464416504, 1.5, 1.4269933700561523, 1.006742000579834, 0.6786835789680481, 0.6736141840616862, 1.2495196461677551, 0.5, 1.0198002258936565, 1.7006419499715169, 1.6704103350639343, 1.0, 1.0579033692677815, 1.6065067291259765, 1.1684763034184773, 1.25, 0.4999423027038574, 0.6953465143839518, 1.671991719139947, 1.245373010635376, 1.5, 0.7145877679189047, 0.5016761620839437, 1.015723983446757, 0.6717681090037028, 1.0, 1.4999995628992715, 2.535693089167277, 1.3078540166219075, 1.6899720297919378, 0.9974491596221924, 0.9999969800313314, 0.5266329050064087, 1.25, 0.754933496316274, 0.6944525241851807, 0.7152414321899414, 1.4218521118164062, 0.5, 1.0887737274169922, 1.0096673170725505, 1.5, 0.7509760856628418, 3.0, 0.735288937886556, 0.5, 1.0, 1.1508525212605794, 1.3760789235432942, 1.0, 0.683318297068278, 1.5, 1.8333333333333333, 0.5006
# ...

# %%
import statistics

# assume you already have these four lists in your namespace:
# min_rf_1, min_rf_2, min_rf_3, min_rf_4

all_lists = [min_rf_1, min_rf_2, min_rf_3, min_rf_4]
labels    = ['delta=0.1', 'delta=0.5', 'delta=0.8', 'delta=1.0']

for label, data in zip(labels, all_lists):
    if not data:
        print(f"{label}: no values")
        continue

    meu = statistics.mean(data)
    sigma = statistics.stdev(data)     # sample standard deviation (ddof=1)
    # σ_pop = statistics.pstdev(data)  # if you want population‐std instead

    print(f"{label:8s}: {meu:.3f}  (std = {sigma:.3f})")
# Out:
# delta=0.1: 1.025  (std = 0.534)
# delta=0.5: 1.027  (std = 0.531)
# delta=0.8: 1.025  (std = 0.517)
# delta=1.0: 1.027  (std = 0.512)

# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics

all_lists = [min_rf_1, min_rf_2, min_rf_3, min_rf_4]
deltas   = np.array([0.1, 0.5, 0.8, 1.0])

# Compute means and standard deviations
means = np.array([statistics.mean(lst) for lst in all_lists])
stds  = np.array([statistics.stdev(lst) for lst in all_lists])

# Fit a linear trendline
coef  = np.polyfit(deltas, means, deg=1)
trend = np.poly1d(coef)

# Generate smooth x for the trendline
x_fit = np.linspace(deltas.min(), deltas.max(), 100)
y_fit = trend(x_fit)

plt.figure(figsize=(8, 6))

# Plot ±1 std “shadow” around the trendline
upper = trend(deltas) + stds
lower = trend(deltas) - stds
plt.fill_between(deltas, lower, upper,
                 color='gray', alpha=0.3,
                 label='±1 Std Shadow')

# Plot the dashed trendline
plt.plot(x_fit, y_fit, linestyle='--', color='black', linewidth=3,
         label=f'Trend: y={coef[0]:.2f}x+{coef[1]:.2f}')

# Plot mean points with error bars
plt.errorbar(deltas, means, yerr=stds,
             marker='o', linestyle='',
             capsize=5, color='blue',
             label='Mean ± Std')

# Add horizontal/vertical margins so labels don't get clipped
plt.margins(x=0.05, y=0.1)

for i, (x, m) in enumerate(zip(deltas, means)):
    # Set horizontal offset and alignment
    dx = -5 if i == len(deltas) - 1 else 5
    ha = 'right' if i == len(deltas) - 1 else 'left'

    # Set vertical offset and alignment: LAST point goes below
    if i == len(deltas) - 1:
        dy = -40  # move annotation below
        va = 'top'
    else:
        dy = 10
        va = 'bottom'


    plt.annotate(
        f"{m:.2f}",
        xy=(x, m),
        xytext=(dx, dy),
        textcoords="offset points",
        ha=ha,
        va="bottom",
        fontsize=24,
        fontweight='bold',
        clip_on=False
    )

plt.xlabel(r'$\delta$', fontsize=28)
plt.ylabel('Mean CMAE', fontsize=28)
# plt.title('Mean ± 1 Std Dev with Trendline Shadow')
plt.xticks(deltas, fontsize=24)
plt.yticks(np.arange(0.5, 2.1, 0.8), fontsize=24)
# plt.legend()
plt.tight_layout()
plt.savefig('/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/all_mae/rf_kappa_constant_delta_min_info_cmae.png', dpi=300)
plt.show()

# %%
import statistics

# assume you already have these four lists in your namespace:
# min_rf_1, min_rf_2, min_rf_3, min_rf_4

all_lists = [min_rl_1, min_rl_2, min_rl_3, min_rl_4]
labels    = ['delta=0.1', 'delta=0.5', 'delta=0.8', 'delta=1.0']

for label, data in zip(labels, all_lists):
    if not data:
        print(f"{label}: no values")
        continue

    meu = statistics.mean(data)
    sigma = statistics.stdev(data)     # sample standard deviation (ddof=1)
    # σ_pop = statistics.pstdev(data)  # if you want population‐std instead

    print(f"{label:8s}: {meu:.3f}  (std = {sigma:.3f})")
# Out:
# delta=0.1: 1.618  (std = 1.377)
# delta=0.5: 0.704  (std = 0.671)
# delta=0.8: 0.663  (std = 0.658)
# delta=1.0: 0.666  (std = 0.664)

# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics

all_lists = [min_rl_1, min_rl_2, min_rl_3, min_rl_4]
deltas   = np.array([0.1, 0.5, 0.8, 1.0])

# Compute means and standard deviations
means = np.array([statistics.mean(lst) for lst in all_lists])
stds  = np.array([statistics.stdev(lst) for lst in all_lists])

# Fit a linear trendline
coef  = np.polyfit(deltas, means, deg=1)
trend = np.poly1d(coef)

# Generate smooth x for the trendline
x_fit = np.linspace(deltas.min(), deltas.max(), 100)
y_fit = trend(x_fit)

plt.figure(figsize=(8, 6))

# Plot ±1 std “shadow” around the trendline
upper = trend(deltas) + stds
lower = trend(deltas) - stds
plt.fill_between(deltas, lower, upper,
                 color='gray', alpha=0.3,
                 label='±1 Std Shadow')

# Plot the dashed trendline
plt.plot(x_fit, y_fit, linestyle='--', color='black', linewidth=3,
         label=f'Trend: y={coef[0]:.2f}x+{coef[1]:.2f}')

# Plot mean points with error bars
plt.errorbar(deltas, means, yerr=stds,
             marker='o', linestyle='',
             capsize=5, color='blue',
             label='Mean ± Std')

# Add horizontal/vertical margins so labels don't get clipped
plt.margins(x=0.05, y=0.1)

# Annotate each mean value; shift last one left
for i, (x, m) in enumerate(zip(deltas, means)):
    # Set horizontal offset and alignment
    dx = -5 if i == len(deltas) - 1 else 5
    ha = 'right' if i == len(deltas) - 1 else 'left'

    # Set vertical offset and alignment: LAST point goes below
    if i == len(deltas) - 1:
        dy = -40  # move annotation below
        va = 'top'
    else:
        dy = 25
        va = 'bottom'

    plt.annotate(
        f"{m:.2f}",
        xy=(x, m),
        xytext=(dx, dy),
        textcoords="offset points",
        ha=ha,
        va="bottom",
        fontsize=24,
        fontweight='bold',
        clip_on=False
    )

plt.xlabel(r'$\delta$', fontsize=28)
plt.ylabel('Mean CMAE', fontsize=28)
# plt.title('Mean ± 1 Std Dev with Trendline Shadow')
plt.xticks(deltas, fontsize=24)
plt.yticks(np.arange(0, 2.1, 0.5), fontsize=24)
# plt.legend()
plt.tight_layout()
plt.savefig(f'{p_cwd}/results/client_level/all_mae/rl_kappa_constant_delta_min_info_cmae.png', dpi=300)
plt.show()

# %%
import statistics

# assume you already have these four lists in your namespace:
# min_rf_1, min_rf_2, min_rf_3, min_rf_4

all_lists = [min_all_1, min_all_2, min_all_3, min_all_4]
labels    = ['delta=0.1', 'delta=0.5', 'delta=0.8', 'delta=1.0']

for label, data in zip(labels, all_lists):
    if not data:
        print(f"{label}: no values")
        continue

    meu = statistics.mean(data)
    sigma = statistics.stdev(data)     # sample standard deviation (ddof=1)
    # σ_pop = statistics.pstdev(data)  # if you want population‐std instead

    print(f"{label:8s}: {meu:.3f}  (std = {sigma:.3f})")
# Out:
# delta=0.1: 1.465  (std = 1.244)
# delta=0.5: 0.787  (std = 0.653)
# delta=0.8: 0.756  (std = 0.644)
# delta=1.0: 0.759  (std = 0.647)

# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics

all_lists = [min_all_1, min_all_2, min_all_3, min_all_4]
kappas   = np.array([0.1, 0.5, 0.8, 1.0])

# Compute means and standard deviations
means = np.array([statistics.mean(lst) for lst in all_lists])
stds  = np.array([statistics.stdev(lst) for lst in all_lists])

# Fit a linear trendline
coef  = np.polyfit(kappas, means, deg=1)
trend = np.poly1d(coef)

# Generate smooth x for the trendline
x_fit = np.linspace(kappas.min(), kappas.max(), 100)
y_fit = trend(x_fit)

plt.figure(figsize=(12, 8))

# Plot ±1 std “shadow” around the trendline
upper = trend(kappas) + stds
lower = trend(kappas) - stds
plt.fill_between(kappas, lower, upper,
                 color='gray', alpha=0.3,
                 label='±1 Std Shadow')

# Plot the dashed trendline
plt.plot(x_fit, y_fit, linestyle='--', color='black',
         label=f'Trend: y={coef[0]:.2f}x+{coef[1]:.2f}')

# Plot mean points with error bars
plt.errorbar(kappas, means, yerr=stds,
             marker='o', linestyle='',
             capsize=5, color='orange',
             label='Mean ± Std')

# Add horizontal/vertical margins so labels don't get clipped
plt.margins(x=0.05, y=0.1)

# Annotate each mean value; shift last one left
for i, (x, m) in enumerate(zip(kappas, means)):
    if i == len(kappas) - 1:
        dx, ha = -5, 'right'
    else:
        dx, ha = 5, 'left'

    plt.annotate(
        f"{m:.2f}",
        xy=(x, m),
        xytext=(dx, 5),          # offset in points
        textcoords="offset points",
        ha=ha,                   # horizontal alignment
        va="bottom",
        fontsize=24,
        fontweight='bold',
        clip_on=False            # allow text outside axes
    )

plt.xlabel(r'$\delta$', fontsize=44)
plt.ylabel('Mean CMAE', fontsize=44)
# plt.title('Mean ± 1 Std Dev with Trendline Shadow')
plt.xticks(kappas, fontsize=38)
plt.yticks(np.arange(0, 3.0, 0.5), fontsize=38)
# plt.legend()
plt.tight_layout()
plt.savefig('/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/all_mae/all_kappa_constant_delta_min_info_cmae.png', dpi=300)
plt.show()

# %% [markdown]
# $\kappa$ variable $\delta$ constant

# %%
import os
import glob
import json
import sys
# Define the directory path
#k01_d1_path_test = '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_kappa_0.1_delta_1.0/local_test'
#k05_d1_path_test = '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_kappa_0.5_delta_1.0/local_test'
#k08_d1_path_test = '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_kappa_0.8_delta_1.0/local_test'
#k1_d1_path_test = '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_rl1_C2/local_test'

k01_d1_path_test = '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2/CFedDC_KT_RL_lambda_min_0.3_lambda_max_0.7_kappa_0.1_delta_1.0/local_test'
k05_d1_path_test = '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2/CFedDC_KT_RL_lambda_min_0.3_lambda_max_0.7_kappa_0.5_delta_1.0/local_test'
k08_d1_path_test = '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2/CFedDC_KT_RL_lambda_min_0.3_lambda_max_0.7_kappa_0.8_delta_1.0/local_test'
k1_d1_path_test = '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2/CFedDC_KT_RL_lambda_min_0.3_lambda_max_0.7_kappa_1.0_delta_1.0/local_test'



# Get a list of all JSON files in the directory
file_list_1 = glob.glob(os.path.join(k01_d1_path_test, '*.json'))
file_list_2 = glob.glob(os.path.join(k05_d1_path_test, '*.json'))
file_list_3 = glob.glob(os.path.join(k08_d1_path_test, '*.json'))
file_list_4 = glob.glob(os.path.join(k1_d1_path_test, '*.json'))

# %%
# Separate files into two categories
resourceless_files_1 = []
resourceful_files_1 = []
resourceless_files_2 = []
resourceful_files_2 = []
resourceless_files_3 = []
resourceful_files_3 = []
resourceless_files_4 = []
resourceful_files_4 = []

for file_path in file_list_1:
    with open(file_path, 'r') as json_file:
        try:
            # Parse the JSON file
            file_data = json.load(json_file)
            # Check the resource category and categorize the file
            if file_data.get('resource_category') == 'Resourceless user':
                resourceless_files_1.append(file_path)
            elif file_data.get('resource_category') == 'Resourceful user':
                resourceful_files_1.append(file_path)
        except json.JSONDecodeError as e:
            print(f"Error reading {file_path}: {e}")


for file_path in file_list_2:
    with open(file_path, 'r') as json_file:
        try:
            # Parse the JSON file
            file_data = json.load(json_file)
            # Check the resource category and categorize the file
            if file_data.get('resource_category') == 'Resourceless user':
                resourceless_files_2.append(file_path)
            elif file_data.get('resource_category') == 'Resourceful user':
                resourceful_files_2.append(file_path)
        except json.JSONDecodeError as e:
            print(f"Error reading {file_path}: {e}")

for file_path in file_list_3:
    with open(file_path, 'r') as json_file:
        try:
            # Parse the JSON file
            file_data = json.load(json_file)
            # Check the resource category and categorize the file
            if file_data.get('resource_category') == 'Resourceless user':
                resourceless_files_3.append(file_path)
            elif file_data.get('resource_category') == 'Resourceful user':
                resourceful_files_3.append(file_path)
        except json.JSONDecodeError as e:
            print(f"Error reading {file_path}: {e}")

for file_path in file_list_4:
    with open(file_path, 'r') as json_file:
        try:
            # Parse the JSON file
            file_data = json.load(json_file)
            # Check the resource category and categorize the file
            if file_data.get('resource_category') == 'Resourceless user':
                resourceless_files_4.append(file_path)
            elif file_data.get('resource_category') == 'Resourceful user':
                resourceful_files_4.append(file_path)
        except json.JSONDecodeError as e:
            print(f"Error reading {file_path}: {e}")

print("Resourceless user files:", resourceless_files_1)
print("Resourceful user files:", resourceful_files_1)
print("Resourceless user files:", resourceless_files_2)
print("Resourceful user files:", resourceful_files_2)
print("Resourceless user files:", resourceless_files_3)
print("Resourceful user files:", resourceful_files_3)
print("Resourceless user files:", resourceless_files_4)
print("Resourceful user files:", resourceful_files_4)
# Out:
# Resourceless user files: ['/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2/CFedDC_KT_RL_lambda_min_0.3_lambda_max_0.7_kappa_0.1_delta_1.0/local_test/user_0_test_round_results.json', '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2/CFedDC_KT_RL_lambda_min_0.3_lambda_max_0.7_kappa_0.1_delta_1.0/local_test/user_100_test_round_results.json', '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2/CFedDC_KT_RL_lambda_min_0.3_lambda_max_0.7_kappa_0.1_delta_1.0/local_test/user_101_test_round_results.json', '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2/CFedDC_KT_RL_lambda_min_0.3_lambda_max_0.7_kappa_0.1_delta_1.0/local_test/user_102_test_round_results.json', '/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/CFedDC_KT_RL_rl1_C2/CFedDC_KT_RL_lambda_min_0.3_lambda_max_0.7_kappa_0.1_delta_1.0/local_test/user_103_test_round_results.json', '/proj/so
# ...

# %%
import json
import statistics

def calculate_stats_min_info_cmae(file_list):
    min_values = []
    for file_path in file_list:
        with open(file_path, 'r') as json_file:
            try:
                file_data = json.load(json_file)
                info_cmae = file_data.get('validation_results', {}).get('info_cmae', [])
                if info_cmae:
                    min_values.append(min(info_cmae))
            except json.JSONDecodeError as e:
                print(f"Error reading {file_path}: {e}")
    print(min_values)
    return min_values 

# Calculate for each group
min_rf_1 = calculate_stats_min_info_cmae(resourceful_files_1)
min_rl_1 = calculate_stats_min_info_cmae(resourceless_files_1)
min_all_1 = calculate_stats_min_info_cmae(file_list_1)

min_rf_2 = calculate_stats_min_info_cmae(resourceful_files_2)
min_rl_2 = calculate_stats_min_info_cmae(resourceless_files_2)
min_all_2 = calculate_stats_min_info_cmae(file_list_2)

min_rf_3 = calculate_stats_min_info_cmae(resourceful_files_3)
min_rl_3 = calculate_stats_min_info_cmae(resourceless_files_3)
min_all_3 = calculate_stats_min_info_cmae(file_list_3)

min_rf_4 = calculate_stats_min_info_cmae(resourceful_files_4)
min_rl_4 = calculate_stats_min_info_cmae(resourceless_files_4)
min_all_4 = calculate_stats_min_info_cmae(file_list_4)
# Out:
# [1.7492550055185951, 1.4440295298894246, 1.2095447063446045, 1.0, 1.1288346250851948, 1.4429757118225097, 1.5781407356262207, 0.4998722871144613, 1.1171231269836426, 0.9419021606445312, 1.0]
# ...

# %%
import statistics

# assume you already have these four lists in your namespace:
# min_rf_1, min_rf_2, min_rf_3, min_rf_4

all_lists = [min_rf_1, min_rf_2, min_rf_3, min_rf_4]
labels    = ['kappa=0.1', 'kappa=0.5', 'kappa=0.8', 'kappa=1.0']

for label, data in zip(labels, all_lists):
    if not data:
        print(f"{label}: no values")
        continue

    meu = statistics.mean(data)
    sigma = statistics.stdev(data)     # sample standard deviation (ddof=1)
    # σ_pop = statistics.pstdev(data)  # if you want population‐std instead

    print(f"{label:8s}: {meu:.3f}  (std = {sigma:.3f})")
# Out:
# kappa=0.1: 1.192  (std = 0.348)
# kappa=0.5: 0.981  (std = 0.506)
# kappa=0.8: 0.997  (std = 0.531)
# kappa=1.0: 1.048  (std = 0.562)

# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics

all_lists = [min_rf_1, min_rf_2, min_rf_3, min_rf_4]
kappas   = np.array([0.1, 0.5, 0.8, 1.0])

# Compute means and standard deviations
means = np.array([statistics.mean(lst) for lst in all_lists])
stds  = np.array([statistics.stdev(lst) for lst in all_lists])

# Fit a linear trendline
coef  = np.polyfit(kappas, means, deg=1)
trend = np.poly1d(coef)

# Generate smooth x for the trendline
x_fit = np.linspace(kappas.min(), kappas.max(), 100)
y_fit = trend(x_fit)

plt.figure(figsize=(8, 6))

# Plot ±1 std “shadow” around the trendline
upper = trend(kappas) + stds
lower = trend(kappas) - stds
plt.fill_between(kappas, lower, upper,
                 color='gray', alpha=0.3,
                 label='±1 Std Shadow')

# Plot the dashed trendline
plt.plot(x_fit, y_fit, linestyle='--', color='black',
         label=f'Trend: y={coef[0]:.2f}x+{coef[1]:.2f}')

# Plot mean points with error bars
plt.errorbar(kappas, means, yerr=stds,
             marker='o', linestyle='',
             capsize=5, color='blue',
             label='Mean ± Std')

# Add horizontal/vertical margins so labels don't get clipped
plt.margins(x=0.05, y=0.1)

# Annotate each mean value; shift last one left
for i, (x, m) in enumerate(zip(kappas, means)):
    # Set horizontal offset and alignment
    dx = -5 if i == len(kappas) - 1 else 5
    ha = 'right' if i == len(kappas) - 1 else 'left'

    # Set vertical offset and alignment: LAST point goes below
    if i == len(kappas) - 1:
        dy = -40  # move annotation below
        va = 'top'
    else:
        dy = 25
        va = 'bottom'

    plt.annotate(
        f"{m:.2f}",
        xy=(x, m),
        xytext=(dx, dy),
        textcoords="offset points",
        ha=ha,
        va="bottom",
        fontsize=24,
        fontweight='bold',
        clip_on=False
    )

plt.xlabel(r'$\kappa$', fontsize=28)
plt.ylabel('Mean CMAE', fontsize=28)
# plt.title('Mean ± 1 Std Dev with Trendline Shadow')
plt.xticks(kappas, fontsize=24)
plt.yticks(np.arange(0.3, 1.8, 0.5), fontsize=24)
# plt.legend()
plt.tight_layout()
plt.savefig('/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/all_mae/rf_delta_constant_kappa_min_info_cmae.png', dpi=300)
plt.show()

# %%
import statistics

# assume you already have these four lists in your namespace:
# min_rf_1, min_rf_2, min_rf_3, min_rf_4

all_lists = [min_rl_1, min_rl_2, min_rl_3, min_rl_4]
labels    = ['kappa=0.1', 'kappa=0.5', 'kappa=0.8', 'kappa=1.0']

for label, data in zip(labels, all_lists):
    if not data:
        print(f"{label}: no values")
        continue

    meu = statistics.mean(data)
    sigma = statistics.stdev(data)     # sample standard deviation (ddof=1)
    # σ_pop = statistics.pstdev(data)  # if you want population‐std instead

    print(f"{label:8s}: {meu:.3f}  (std = {sigma:.3f})")
# Out:
# kappa=0.1: 1.019  (std = 1.417)
# kappa=0.5: 0.691  (std = 0.643)
# kappa=0.8: 0.671  (std = 0.641)
# kappa=1.0: 0.637  (std = 0.640)

# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics

all_lists = [min_rl_1, min_rl_2, min_rl_3, min_rl_4]
kappas   = np.array([0.1, 0.5, 0.8, 1.0])

# Compute means and standard deviations
means = np.array([statistics.mean(lst) for lst in all_lists])
stds  = np.array([statistics.stdev(lst) for lst in all_lists])

# Fit a linear trendline
coef  = np.polyfit(kappas, means, deg=1)
trend = np.poly1d(coef)

# Generate smooth x for the trendline
x_fit = np.linspace(kappas.min(), kappas.max(), 100)
y_fit = trend(x_fit)

plt.figure(figsize=(8, 6))

# Plot ±1 std “shadow” around the trendline
upper = trend(kappas) + stds
lower = trend(kappas) - stds
plt.fill_between(kappas, lower, upper,
                 color='gray', alpha=0.3,
                 label='±1 Std Shadow')

# Plot the dashed trendline
plt.plot(x_fit, y_fit, linestyle='--', color='black',
         label=f'Trend: y={coef[0]:.2f}x+{coef[1]:.2f}')

# Plot mean points with error bars
plt.errorbar(kappas, means, yerr=stds,
             marker='o', linestyle='',
             capsize=5, color='blue',
             label='Mean ± Std')

# Add horizontal/vertical margins so labels don't get clipped
plt.margins(x=0.05, y=0.1)

# Annotate each mean value; shift last one left
for i, (x, m) in enumerate(zip(kappas, means)):
    # Set horizontal offset and alignment
    dx = -5 if i == len(kappas) - 1 else 5
    ha = 'right' if i == len(kappas) - 1 else 'left'

    # Set vertical offset and alignment: LAST point goes below
    if i == len(kappas) - 1:
        dy = -40  # move annotation below
        va = 'top'
    else:
        dy = 25
        va = 'bottom'

    plt.annotate(
        f"{m:.2f}",
        xy=(x, m),
        xytext=(dx, dy),
        textcoords="offset points",
        ha=ha,
        va="bottom",
        fontsize=24,
        fontweight='bold',
        clip_on=False
    )

plt.xlabel(r'$\kappa$', fontsize=28)
plt.ylabel('Mean CMAE', fontsize=28)
# plt.title('Mean ± 1 Std Dev with Trendline Shadow')
plt.xticks(kappas, fontsize=24)
plt.yticks(np.arange(0, 3.0, 0.5), fontsize=24)
# plt.legend()
plt.tight_layout()
plt.savefig('/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/all_mae/rl_delta_constant_kappa_min_info_cmae.png', dpi=300)
plt.show()

# %%
import statistics

# assume you already have these four lists in your namespace:
# min_rf_1, min_rf_2, min_rf_3, min_rf_4

all_lists = [min_all_1, min_all_2, min_all_3, min_all_4]
labels    = ['kappa=0.1', 'kappa=0.5', 'kappa=0.8', 'kappa=1.0']

for label, data in zip(labels, all_lists):
    if not data:
        print(f"{label}: no values")
        continue

    meu = statistics.mean(data)
    sigma = statistics.stdev(data)     # sample standard deviation (ddof=1)
    # σ_pop = statistics.pstdev(data)  # if you want population‐std instead

    print(f"{label:8s}: {meu:.3f}  (std = {sigma:.3f})")
# Out:
# kappa=0.1: 1.023  (std = 1.400)
# kappa=0.5: 0.729  (std = 0.634)
# kappa=0.8: 0.738  (std = 0.633)
# kappa=1.0: 0.743  (std = 0.646)

# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics

all_lists = [min_all_1, min_all_2, min_all_3, min_all_4]
kappas   = np.array([0.1, 0.5, 0.8, 1.0])

# Compute means and standard deviations
means = np.array([statistics.mean(lst) for lst in all_lists])
stds  = np.array([statistics.stdev(lst) for lst in all_lists])

# Fit a linear trendline
coef  = np.polyfit(kappas, means, deg=1)
trend = np.poly1d(coef)

# Generate smooth x for the trendline
x_fit = np.linspace(kappas.min(), kappas.max(), 100)
y_fit = trend(x_fit)

plt.figure(figsize=(12, 8))

# Plot ±1 std “shadow” around the trendline
upper = trend(kappas) + stds
lower = trend(kappas) - stds
plt.fill_between(kappas, lower, upper,
                 color='gray', alpha=0.3,
                 label='±1 Std Shadow')

# Plot the dashed trendline
plt.plot(x_fit, y_fit, linestyle='--', color='black',
         label=f'Trend: y={coef[0]:.2f}x+{coef[1]:.2f}')

# Plot mean points with error bars
plt.errorbar(kappas, means, yerr=stds,
             marker='o', linestyle='',
             capsize=5, color='blue',
             label='Mean ± Std')

# Add horizontal/vertical margins so labels don't get clipped
plt.margins(x=0.05, y=0.1)

# Annotate each mean value; shift last one left
for i, (x, m) in enumerate(zip(kappas, means)):
    if i == len(kappas) - 1:
        dx, ha = -5, 'right'
    else:
        dx, ha = 5, 'left'

    plt.annotate(
        f"{m:.2f}",
        xy=(x, m),
        xytext=(dx, 5),          # offset in points
        textcoords="offset points",
        ha=ha,                   # horizontal alignment
        va="bottom",
        fontsize=24,
        fontweight='bold',
        clip_on=False            # allow text outside axes
    )

plt.xlabel(r'$\kappa$', fontsize=44)
plt.ylabel('Mean CMAE', fontsize=44)
# plt.title('Mean ± 1 Std Dev with Trendline Shadow')
plt.xticks(kappas, fontsize=38)
plt.yticks(np.arange(0, 3.0, 0.5), fontsize=38)
# plt.legend()
plt.tight_layout()
plt.savefig('/proj/sourasb-220503/TCSS-DIPA2/Fed-DIPA2/results/client_level/all_mae/all_delta_constant_kappa_min_info_cmae.png', dpi=300)
plt.show()
