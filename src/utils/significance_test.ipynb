# %%
import numpy as np
from scipy.stats import ttest_rel, wilcoxon
from scipy.stats import mannwhitneyu

# %% [markdown]
# # or 10 Different Independent runs: Value reported

# %%
feddc = [0.7735012355585843, 0.7703833054121043, 0.7689890972969733, 0.7836149069648293, 0.7472183667584597, 0.7223838646354701, 0.7595057921546593, 0.7301505347136024]

cfeddc = [0.7451223208578824, 0.765893910537889, 0.7349595007306904, 0.7499388585075953, 0.7456926157643319, 0.7670570032834444, 0.7424367328248866, 0.7313875465030607]

# %%
# Paired t-test
t_stat, p_val = ttest_rel(feddc, cfeddc)
print("Paired t-test:", t_stat, p_val)

# Wilcoxon test
w_stat, p_val = wilcoxon(feddc, cfeddc)
print("Wilcoxon test:", w_stat, p_val)
# Out:
# Paired t-test: 0.9955911876051511 0.3526109677747913
# Wilcoxon test: 9.0 0.25

# %%
feddc = [27.16228120065766, 7.453063987933441, 3.6442803218291795, 2.7169267024037946, 2.657939782614927, 2.1115148631661427, 1.596839234983396, 2.1018335812805615, 2.211885076103989, 2.16725938174744, 1.6917052230851015, 1.5678792161789672, 1.4616218460378823, 1.5723324942681625, 1.432268762925491, 1.4099468951072758, 1.575367821073191, 2.3548430385429713, 2.7057315174210084, 1.8453523482203351, 1.4448130459312505, 1.4998518043938778, 1.3743846347821014, 1.484284075572836, 2.4941758797551046, 1.4708258956001796, 1.5890806110619695, 1.599637062636891, 1.559336884003697, 1.383736818384977]
cfeddc = [146.91614850773556, 6.813898036310786, 4.670550000992855, 3.3634801426825063, 2.807504560108538, 2.951141887247211, 3.243532919346885, 3.2104341724111913, 3.167168601231041, 3.380770141281832, 3.0946809995028906, 3.2372719287312055, 2.9907504024922713, 3.300423396602858, 3.229073213557603, 3.3440938059462177, 3.1971799586967524, 3.5007000605081338, 3.181105123776378, 3.036152356752643, 2.91000643046416, 3.181214293697065, 2.9934420757806794, 3.921794079779307, 3.892317189746165, 3.2106698975803205, 3.162023175804636, 3.036555793023471, 2.486957581799506, 2.5323685134701455]

# %%
# Paired t-test
t_stat, p_val = ttest_rel(feddc, cfeddc)
print("Paired t-test:", t_stat, p_val)

# Wilcoxon test
w_stat, p_val = wilcoxon(feddc, cfeddc)
print("Wilcoxon test:", w_stat, p_val)

u_stat, p_val = mannwhitneyu(feddc, cfeddc, alternative="two-sided")
print("Mann-Whitney U test:", u_stat, p_val)
# Out:
# Paired t-test: -1.3214192828498845 0.19669269559121286
# Wilcoxon test: 3.0 9.313225746154785e-09
# Mann-Whitney U test: 90.0 1.0665677738596446e-07

# %%
# Out:
# Mann-Whitney U test: 90.0 1.0665677738596446e-07
