FedDC_DL_3  = [75.63794869973871, 11.95785578577774, 3.599895701236714, 2.7312958544971027, 2.4945330873181923, 3.3701965441022126, 2.6970302733617775, 3.6413374465506623, 2.8485939962544826, 3.571878399478332, 2.9925084261121238, 3.368243218028519, 2.998218110163605, 3.290428421354521, 3.4495947314374047, 3.2160810843260603, 2.7856976548931014, 2.8844051646982245, 2.984655436609195, 2.778453083752783, 2.5033270589146017, 2.7861623649896194, 2.7839304481274487, 2.8623736990588546, 2.59547182476079, 4.240262152687735, 2.3749220889860263, 2.344002332450565, 1.4014753294579778, 2.049337134216771]

CFedDC_DR_4 =  [131.8611489527228, 2.9174403368163264, 2.4218242063350215, 2.4983982319407487, 2.005267689700503, 2.014331827503556, 2.112676826114866, 2.4104169704912968, 2.4171657216224296, 2.806255313804588, 2.4669015525764677, 2.461013511740278, 2.3263485484363358, 2.105460188512556, 2.0757973766170017, 2.0925976026022064, 2.003277824976627, 1.9512873815773217, 1.8483843368898147, 1.8763738177450913, 1.6975994556378429, 1.7858975490376958, 1.6289885271358506, 1.7387427647079605, 1.780732276066226, 1.7603221528855966, 1.7558548656525668, 1.6757405189246923, 1.7573226166398388, 1.84860093958499]
FedDC_DR_3 = [14.841580905877157, 8.919258175160259, 3.2952594162244475, 2.821655554841058, 2.649566280543864, 2.9369005436958444, 2.614735209158832, 3.528309757290677, 3.2726687472501346, 3.6160349116922816, 3.3066032583669998, 3.0937907548726, 3.6159930183503786, 5.16571321062211, 3.3513061726709665, 2.9357980726129176, 2.0895517585399555, 3.018739610877324, 2.0911846550551756, 3.464747087224326, 1.9699419022311686, 5.507843636395335, 1.7760041268289877, 2.519505494757912, 1.6933162652753546, 2.1911359535951456, 1.7345767568466497, 5.661080377097038, 1.3084466922720637, 2.1629761994796426]


merged_avg_0_cfeddc = list(np.mean([CFedDC_DL_0, CFedDC_DR_0], axis=0))
merged_avg_1_cfeddc = list(np.mean([CFedDC_DL_1, CFedDC_DR_1], axis=0))
merged_avg_2_cfeddc = list(np.mean([CFedDC_DL_2, CFedDC_DR_2], axis=0))
merged_avg_3_cfeddc = list(np.mean([CFedDC_DL_3, CFedDC_DR_3], axis=0))
merged_avg_4_cfeddc = list(np.mean([CFedDC_DL_4, CFedDC_DR_4], axis=0))

merged_avg_0_feddc = list(np.mean([FedDC_DL_0, FedDC_DR_0], axis=0))
merged_avg_1_feddc = list(np.mean([FedDC_DL_1, FedDC_DR_1], axis=0))
merged_avg_2_feddc = list(np.mean([FedDC_DL_2, FedDC_DR_2], axis=0))
merged_avg_3_feddc = list(np.mean([FedDC_DL_3, FedDC_DR_3], axis=0))
merged_avg_4_feddc = list(np.mean([FedDC_DL_3, FedDC_DR_3], axis=0))

# %%
# Wilcoxon test
w_stat, p_val = wilcoxon(feddc, cfeddc)
print("Wilcoxon test:", w_stat, p_val)
# Out:
# Paired t-test: 0.9955911876051511 0.3526109677747913
# Wilcoxon test: 9.0 0.25

# %% [markdown]
# Run 0

# %%
# Wilcoxon test _
w_stat, p_val = wilcoxon(merged_avg_0_cfeddc, merged_avg_0_feddc)
print("Wilcoxon test:", w_stat, p_val)

u_stat, p_val = mannwhitneyu(merged_avg_0_cfeddc, merged_avg_0_feddc, alternative="two-sided")
print("Mann-Whitney U test:", u_stat, p_val)
# Out:
# Wilcoxon test: 4.0 1.30385160446167e-08
# Mann-Whitney U test: 143.0 5.858675152587995e-06

# %% [markdown]
# Run 1

# %%
# Wilcoxon test
w_stat, p_val = wilcoxon(merged_avg_1_cfeddc, merged_avg_1_feddc)
print("Wilcoxon test:", p_val)

u_stat, p_val = mannwhitneyu(merged_avg_1_cfeddc, merged_avg_1_feddc, alternative="two-sided")
print("Mann-Whitney U test:",u_stat,  p_val)
# Out:
# Wilcoxon test: 4.4075772166252136e-05
# Mann-Whitney U test: 129.0 2.15403414258883e-06

# %% [markdown]
# Run 2

# %%
# Wilcoxon test
w_stat, p_val = wilcoxon(merged_avg_2_cfeddc, merged_avg_2_feddc)
print("Wilcoxon test:", w_stat, p_val)

u_stat, p_val = mannwhitneyu(merged_avg_2_cfeddc, merged_avg_2_feddc, alternative="two-sided")
print("Mann-Whitney U test:",u_stat,  p_val)
# Out:
# Wilcoxon test: 56.0 0.00011058151721954346
# Mann-Whitney U test: 156.0 1.4298355871314211e-05

# %% [markdown]
# Run 3

# %%
# Wilcoxon test
w_stat, p_val = wilcoxon(merged_avg_3_cfeddc, merged_avg_3_feddc)
print("Wilcoxon test:", w_stat, p_val)

u_stat, p_val = mannwhitneyu(merged_avg_3_cfeddc, merged_avg_3_feddc, alternative="two-sided")
print("Mann-Whitney U test:", u_stat, p_val)
# Out:
# Wilcoxon test: 79.0 0.001038169488310814
# Mann-Whitney U test: 172.0 4.0839534518280284e-05

# %% [markdown]
# Run 4

# %%
# Wilcoxon test
w_stat, p_val = wilcoxon(merged_avg_4_cfeddc, merged_avg_4_feddc)
print("Wilcoxon test:", w_stat, p_val)

u_stat, p_val = mannwhitneyu(merged_avg_4_cfeddc, merged_avg_4_feddc, alternative="two-sided")
print("Mann-Whitney U test:", u_stat, p_val)
# Out:
# Wilcoxon test: 116.0 0.015460003167390823
# Mann-Whitney U test: 233.0 0.0013703325610487653

# %% [markdown]
# For each client/user, you took the last 5 CMAE values (from their training/validation curve) and averaged them.
#
# This gives you a stabilized CMAE per user (not just the noisy final round).
#
# Now you have 442 such values (one per user) in each run.
#
# 🔹 Step 2. Average across users
#
# Then you averaged these 442 values into one number per run.
#
# This represents the average client performance (CMAE) at the end of training for that run.
#
# It’s a global summary: “How well did the algorithm perform across all users, on average, at convergence?”
#
# So after this step, each run contributes one aggregate CMAE score.

# %%
feddc = [1.8704, 2.6537, 2.7282, 2.0471, 2.5018]
cfeddc = [1.5089, 1.6011, 1.5936, 1.6257, 1.4969]

u_stat, p_val = mannwhitneyu(cfeddc, feddc, alternative="two-sided")
print("Mann-Whitney U test:", u_stat, p_val)
# Out:
# Mann-Whitney U test: 0.0 0.007936507936507936

# %% [markdown]
# Overall performance (Min_CMAE across all clients)

# %%
feddc_0 = [0.7735012355585843, 0.7703833054121043, 0.7689890972969733, 0.7836149069648293, 0.7472183667584597, 0.7223838646354701, 0.7595057921546593, 0.7301505347136024]

cfeddc = [0.7451223208578824, 0.765893910537889, 0.7349595007306904, 0.7499388585075953, 0.7456926157643319, 0.7670570032834444, 0.7424367328248866, 0.7313875465030607]
